# %% [markdown]
# ### Task: Explore one of the dataset Iris.
# Load Iris.csv and verify the number of features and the class labels.

# %% [markdown]
# ## Question 1
#
# Load the data from the file using the techniques learned today. Examine it.
#
# Determine the following:
#
# * The number of data points (rows). (*Hint:* check out the dataframe `.shape` attribute.)
# * The column names. (*Hint:* check out the dataframe `.columns` attribute.)
# * The data types for each column. (*Hint:* check out the dataframe `.dtypes` attribute.)

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #### Give the reason: why the description of the 'Species' column is not there in the above output?

# %%
data.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ### Q. Change the ids starting from 0 instead 1

# %% [markdown]
# ### Q. Display one row of data

# %% [markdown]
# ### Q. Get the total number of samples

# %% [markdown]
# ### Q. Get the column titles and datatypes

# %% [markdown]
# ### Q. Calculate number of samples in each class

# %% [markdown]
# ### Remove the word 'Iris-' from the class names

# %% [markdown]
# ### Q. Verify whether any null values in the data

# %% [markdown]
# ### Drop the rows with missing (null) values

# %% [markdown]
# ### Drop the columns with missing (null) values

# %% [markdown]
# ### Fill the missing values using a constant

# %% [markdown]
# ### Q. Obtain the features in X and the categories in y

# %% [markdown]
# ### Obtain the statistical description of the features with mean, median, 25% and 75% percentile score, as well, the range.

# %% [markdown]
# ### Get the mean, median of the feature values for each class

# %% [markdown]
# ### Obtain both the mean and meadian together/aggregate class-wise

# %% [markdown]
# ### Get the Histogram of single feature and multiple faetures

# %% [markdown]
# ### Get the scatter plot for visualization Sepal Width v/s Sepal length

# %% [markdown]
# ### Decide the most important feature(s) for classification among the given four features by observing the scatter plot of feature versus the class

# %% [markdown]
# ### Obtain PairPlot using Seaborn library

# %%
import seaborn as sns

# %%
sns.set_context('talk')
sns.pairplot(data, hue='Species');

# %% [markdown]
# ### Achieve histogram and boxplot plotting through SeaBorn
