# %%
from sklearn.svm import SVR
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn import datasets

# %%
df=datasets.load_diabetes(as_frame=True).frame

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
df.shape
# Out:
# (442, 11)

# %% [markdown]
# ### Feature Target Selection

# %%
X=df.drop("target",axis=1)
y=df["target"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
y_train
# Out:
# 225    208.0
# 412    261.0
# 118    179.0
# 114    258.0
# 364    262.0
#        ...
# 106    134.0
# 270    202.0
# 348    148.0
# 435     64.0
# 102    302.0
# Name: target, Length: 309, dtype: float64

# %%
y_train.values.reshape(-1, 1) #Convert data into 2 dimensional data
# Out:
# array([[208.],
#        [261.],
#        [179.],
#        [258.],
#        [262.],
#        [ 51.],
#        [237.],
#        [ 71.],
#        [139.],
#        [268.],
#        [ 69.],
#        [317.],
#        [249.],
#        [154.],
#        [192.],
#        [116.],
#        [ 81.],
#        [122.],
#        [259.],
#        [191.],
#        [292.],
#        [ 55.],
#        [107.],
#        [210.],
#        [ 91.],
#        [253.],
#        [ 85.],
#        [252.],
#        [ 59.],
#        [ 78.],
#        [200.],
#        [ 78.],
#        [245.],
#        [175.],
#        [ 42.],
#        [127.],
#        [ 53.],
#        [ 94.],
#        [104.],
#        [199.],
#        [265.],
#        [281.],
#        [248.],
#        [257.],
#        [215.],
#        [303.],
#        [170.],
#        [ 59.],
#        [277.],
#        [209.],
#        [138.],
#        [198.],
#        [124.],
#        [ 96.],
#        [288.],
#        [225.],
#        [265.],
#        [101.],
# ...

# %%
y_train.values.reshape(-1, 1).ravel()  #.ravel() faltten the data
# Out:
# array([208., 261., 179., 258., 262.,  51., 237.,  71., 139., 268.,  69.,
#        317., 249., 154., 192., 116.,  81., 122., 259., 191., 292.,  55.,
#        107., 210.,  91., 253.,  85., 252.,  59.,  78., 200.,  78., 245.,
#        175.,  42., 127.,  53.,  94., 104., 199., 265., 281., 248., 257.,
#        215., 303., 170.,  59., 277., 209., 138., 198., 124.,  96., 288.,
#        225., 265., 101.,  55., 198.,  51., 252.,  64., 220., 131., 212.,
#        142., 103., 155., 121.,  86., 111.,  65., 131.,  51., 128., 141.,
#         48., 109., 178.,  88.,  84., 216., 150.,  60.,  96., 190.,  74.,
#        279., 182., 160., 245., 276., 174., 180., 150., 196., 138.,  97.,
#        246., 321., 308., 109.,  69., 182., 258., 161., 178., 214.,  45.,
#        150., 160.,  55., 197., 185., 268., 310., 123.,  68.,  72., 185.,
#        144., 147., 168., 178., 246., 151., 127.,  83., 332., 152., 109.,
#         90.,  66., 214.,  85., 129.,  89., 259., 229., 200.,  77.,  54.,
# ...

# %% [markdown]
# ### Scaling

# %%
y_scaler=StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train.values.reshape(-1, 1)).ravel()  
y_test_scaled = y_scaler.transform(y_test.values.reshape(-1,1)).ravel()

# y_train data in 1D 1st convert into 2D and after tranform again converted back to 1D uding ravel()

# %% [markdown]
# ### Model selection & Training

# %%
model=SVR()
model.fit(X_train,y_train_scaled)
# Out:
# SVR()

# %%
y_test_pred_scaled=model.predict(X_test)
y_train_pred_scaled=model.predict(X_train)

# %% [markdown]
# ### Evalution

# %%
print("train r2: ", r2_score(y_train_scaled, y_train_pred_scaled))
print("test r2: ", r2_score(y_test_scaled, y_test_pred_scaled))
# Out:
# train r2:  0.6596361676267714
# test r2:  0.48844443151651906

# %%
# Linear
model = SVR(kernel="linear")

model.fit(X_train, y_train_scaled)

y_test_pred_scaled = model.predict(X_test)
y_train_pred_scaled = model.predict(X_train)

print("train r2: ", r2_score(y_train_scaled, y_train_pred_scaled))
print("test r2: ", r2_score(y_test_scaled, y_test_pred_scaled))
# Out:
# train r2:  0.45191229982475256
# test r2:  0.4433761323833776

# %%
# Polynomial
model = SVR(kernel="poly")

model.fit(X_train, y_train_scaled)

y_test_pred_scaled = model.predict(X_test)
y_train_pred_scaled = model.predict(X_train)

print("train r2: ", r2_score(y_train_scaled, y_train_pred_scaled))
print("test r2: ", r2_score(y_test_scaled, y_test_pred_scaled))
# Out:
# train r2:  0.5790920834310538
# test r2:  0.2420377103810777

# %% [markdown]
# # Hyperparameter tuning usign GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "C": [1, 2, 5, 10, 50, 100],
    "kernel": ["rbf", "linear"],
    "epsilon": [0.01, 0.1, 0.2, 0.3, 0.5]
}

# %%
svr = SVR()

grid_search = GridSearchCV(svr, param_grid, scoring="r2", cv=5)

grid_search.fit(X_train, y_train_scaled)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [1, 2, 5, 10, 50, 100],
#                          'epsilon': [0.01, 0.1, 0.2, 0.3, 0.5],
#                          'kernel': ['rbf', 'linear']},
#              scoring='r2')

# %%
print("best params - ", grid_search.best_params_)
# Out:
# best params -  {'C': 10, 'epsilon': 0.1, 'kernel': 'linear'}

# %%
best_model=SVR(kernel="linear",C=10,epsilon=0.1)
best_model.fit(X_train,y_train_scaled)
y_test_pred_sacled=best_model.predict(X_test)
y_train_pred_scaled = best_model.predict(X_train)

print("train r2:",r2_score(y_train_scaled,y_train_pred_scaled))
print("test r2: ", r2_score(y_test_scaled, y_test_pred_scaled))
# Out:
# train r2: 0.5151066486918875
# test r2:  0.2420377103810777

# %% [markdown]
# ### Direct Simplified version of SVM model LinearSVR-with less paramters

# %%
from sklearn.svm import LinearSVR

model = LinearSVR(C=10, epsilon=0.1, max_iter=5000)

model.fit(X_train, y_train_scaled)

y_test_pred_scaled = model.predict(X_test)
y_train_pred_scaled = model.predict(X_train)

print("train r2: ", r2_score(y_train_scaled, y_train_pred_scaled))
print("test r2: ", r2_score(y_test_scaled, y_test_pred_scaled))
# Out:
# train r2:  0.5151070858009521
# test r2:  0.47437031204015456
